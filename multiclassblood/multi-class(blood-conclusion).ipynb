# %% [markdown]
# In this I am adding data set "BloodMNIST"
# with the nessearcy changes in loss function (we will add 'categorical_crossentropy' ) and we will use softmax activation code
# ## 1.2BloodMNISTbb
# In This we will see the graphs increasing graph with 2 intersection and at last it has increased in accuracy . When it comes to loss its right below the validation data.
# but atlast accuracy is showing above train data
#
# In  loss it is showing below train data
#
#
# we are also getting accuracy score of 1.0 and loose 0f 0.0
#
# ## 2.2BloodMNISTbb
# In this we will use  only dense layers in the model architecture which will give a increasing accuracy which is slightly above validation data
#
# the loss is a curve below the training data
#
# it is giving accuracy of 1.0 and loss of 0.04
#
# ## 3.2BloodMNISTbb
# In this I am using my own architecture with 2 convalutional layer and with 2 dense layers
#
# which is giving a graph with increasing accuracy with slight intersection and it increased at last
#
# In loose it is below the training data
#
# It is giving accuracy of 1.0 and loose of 0.96
#
# by seeing graphs of bove 2nd models i can say d model is good compare to first and second model because of its increasing accuracy and decreasing loose in graph with a loose of 0.04 and accuracy of 1
